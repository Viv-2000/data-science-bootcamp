# %% [markdown]
# # Importing Modules
# ### 1. Importing and Using Modules
#
# Import the `math` module and use it to calculate the square root of 25 and the sine of 90 degrees.

# %%
# math library has most maths functions we need to perform 
import math

print(math.sqrt(25))  
print(math.sin(math.radians(90)))
# Out:
# 5.0
# 1.0

# %% [markdown]
# ### 2. Aliasing Modules
#
# Import the `datetime` module with an alias and use it to print the current date and time.

# %%
import datetime as dt

print(dt.datetime.now())
# Out:
# 2026-03-05 17:14:58.398486

# %% [markdown]
# ### 3. Importing Specific Functions
#
# Import the `randint` function from the `random` module and use it to generate a random integer between 1 and 100.

# %%
from random import randint
# random.randint(a,b) returns a random integer between a and b, both endpoints inclusive
# random.uniform(a,b) returns a random floating point between a and b, both endpoints inclusive
# random.choice(lst) randomly chooses a value from the entered list of elements
print(randint(1, 100))
# Out:
# 60

# %% [markdown]
# ### 4. Importing Multiple Functions
#
# Import the `sqrt` and `pow` functions from the `math` module and use them to calculate the square root of 16 and 2 raised to the power of 3.

# %%
from math import sqrt, pow

print(sqrt(16))  
print(pow(2, 3))
# Out:
# 4.0
# 8.0

# %% [markdown]
# ### 5. Handling Import Errors
#
# Write code that attempts to import a non-existent module and gracefully handles the import error by printing an error message.

# %%
try:
    import non_existent_module
except ImportError as e:
    print(f"Error importing module: {e}")
except Exception as e:
    print(e)
# Out:
# Error importing module: No module named 'non_existent_module'

# %% [markdown]
# ## Standard Library Overview
# ### 6. Working with the `os` Module
#
# Use the `os` module to create a new directory, list the contents of the current directory, and remove the newly created directory.

# %%
import os

# Create a new directory
os.mkdir('new_directory')

# List contents of the current directory
print(os.listdir('.'))

# Remove the newly created directory
os.rmdir('new_directory')
print(os.listdir('.'))
# Out:
# ['13. classes- overall.ipynb', '.DS_Store', '3. lists.ipynb', '1. basics.ipynb', '4. tuple.ipynb', '17. logging.ipynb', 'new_directory', '5. sets.ipynb', '8. packages and imports.ipynb', '18. multithreading.ipynb', '12. inheritance and polymorphism.ipynb', '2. basic control flow, loops.ipynb', '15. numpy- arrays.ipynb', '19. multiprocessing.py', '14. iterators, generators, decorators.ipynb', '6. dictionaries.ipynb', '10. exception handling.ipynb', '20. flask', '9. file handling.ipynb', '16. pandas- series and dataframes.ipynb', '7. advance functions.ipynb', '11. classes and objects.ipynb']
# ...

# %% [markdown]
# ### 7. Working with the `sys` Module
#
# Use the `sys` module to print the Python version currently in use and the command-line arguments passed to the script.

# %%
import sys

print(f"Python version: {sys.version}")
print(f"Command-line arguments: {sys.argv}")
# Out:
# Python version: 3.12.0 | packaged by Anaconda, Inc. | (main, Oct  2 2023, 12:22:05) [Clang 14.0.6 ]
# Command-line arguments: ['/Users/vivekaggarwal/Desktop/data science/python/venv1/lib/python3.12/site-packages/ipykernel_launcher.py', '--f=/Users/vivekaggarwal/Library/Jupyter/runtime/kernel-v3c1b5f9c35fe3325283f9e9a16f98d49b5f8654cd.json']

# %% [markdown]
# ### 8. Working with the `math` Module
#
# Use the `math` module to calculate the greatest common divisor (GCD) of two numbers and the factorial of a number.

# %%
import math

print(math.gcd(48, 18)) 
print(math.factorial(5))
# Out:
# 6
# 120

# %% [markdown]
# ### 9. Working with the `datetime` Module
#
# Use the `datetime` module to print the current date, calculate the date 100 days from today, and determine the day of the week for a given date.

# %%
import datetime

# Current date
today = datetime.date.today()
print(f"Today's date: {today}")

# Date 100 days from today
future_date = today + datetime.timedelta(days=100)
print(f"Date 100 days from today: {future_date}")

# Day of the week for a given date
given_date = datetime.date(2022, 1, 1)
print(f"Day of the week for 2022-01-01: {given_date.strftime('%A')}")
# Out:
# Today's date: 2026-03-05
# Date 100 days from today: 2026-06-13
# Day of the week for 2022-01-01: Saturday

# %% [markdown]
# ### 10. Working with the `random` Module
#
# Use the `random` module to generate a list of 5 random numbers between 1 and 50 and shuffle the elements of a list.

# %%
import random

# List of 5 random numbers between 1 and 50
random_numbers = [random.randint(1, 50) for _ in range(5)]
print(random_numbers)

# Shuffle a list
lst = [1, 2, 3, 4, 5]
random.shuffle(lst)
print(lst)
# Out:
# [36, 9, 12, 21, 29]
# [4, 5, 2, 1, 3]

# %% [markdown]
# ##  Creating and Using Packages
# ### 11. Creating a Simple Package
#
# Create a package named `mypackage` with two modules: `module1` and `module2`. `module1` should contain a function that adds two numbers, and `module2` should contain a function that multiplies two numbers. Write code to use these functions.

# %%
# File structure:
# mypackage/
#   __init__.py         this is very important to tell the interpreter that the modules inside this folder are part of the package
#   module1.py
#   module2.py

# Content of module1.py
# def add(a, b):
#     return a + b

# Content of module2.py
# def multiply(a, b):
#     return a * b

# Using the package
try:
    from mypackage import module1, module2

    print(module1.add(2, 3))  
    print(module2.multiply(2, 3))  
except Exception as e:
    print('please create the modules as defined above in the same structure')
# Out:
# 5
# 6

# %% [markdown]
# ### 12. Using `__init__.py`
#
# Modify the `mypackage` package to include an `__init__.py` file that imports the functions from `module1` and `module2`. Write code to use these functions.

# %%
# Content of __init__.py
# from .module1 import add
# from .module2 import multiply

# Using the package
try:
    from mypackage import add, multiply
    print(add(2, 3))  
    print(multiply(2, 3))  
except Exception as e:
    print('please create the modules as defined above in the same structure')

''' This relative import only works when Python knows it's inside a package, which happens when you run: >>> python main.py 
    But Jupyter runs cells independently, so Python doesn't know the parent package.  '''
# Out:
# please create the modules as defined above in the same structure
# " This relative import only works when Python knows it's inside a package, which happens when you run: >>> python main.py \n    But Jupyter runs cells independently, so Python doesn't know the parent package.  "

# %% [markdown]
# ### 13. Importing from a Package
#
# Write code to import and use the functions from `mypackage` without explicitly importing `module1` and `module2`.

# %%
try:
    import mypackage

    print(mypackage.module1.add(2, 3))  
    print(mypackage.module2.multiply(2, 3))  
except Exception as e:
    print('please create the modules as defined above in the same structure')
# Out:
# 5
# 6

# %% [markdown]
# ### 14. Relative Imports
#
# Create a subpackage named `subpackage` within `mypackage` and create `module3` into `subpackage` with same content as `module 2`. Modify the import statements in `__init__.py` to use relative imports. Write code to use the functions from both modules.

# %%
# File structure:
# mypackage/
#   __init__.py
#   module1.py
#   module2.py
#   subpackage/
#     __init__.py
#     module3.py

# Content of __init__.py in mypackage
# from .module1 import add
# from .subpackage.module3 import multiply

# Using the package
try:
    from mypackage import add, multiply
    print(add(2, 3)) 
    print(multiply(2, 3))  
except Exception as e:
    print('please create the modules as defined above in the same structure')
# Out:
# please create the modules as defined above in the same structure

# %% [markdown]
# ### 15. Handling Package Import Errors
#
# Write code that attempts to import a non-existent function from `mypackage` and gracefully handles the import error by printing an error message.

# %%
try:
    from mypackage import non_existent_function
except ImportError as e:
    print(f"Error importing function: {e}")
# Out:
# Error importing function: cannot import name 'non_existent_function' from 'mypackage' (/Users/vivekaggarwal/Desktop/data science/4. code files/8. packages and imports/mypackage/__init__.py)
